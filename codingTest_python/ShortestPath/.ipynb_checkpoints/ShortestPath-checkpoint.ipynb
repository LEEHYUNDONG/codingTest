# %%
# 미래 도시 품
INF = int(1e9)

n, m = map(int, input().split())
graph = [[INF]*(n+1) for _ in range(n+1)]

for a in range(1, n+1):
    for b in range(1, n+1):
        if a == b:
            graph[a][b] = 0
            
for _ in range(m):
    a, b = map(int, input().split())
    graph[a][b] = graph[b][a] = 1
    
for k in range(1, n+1):
    for a in range(1, n+1):
        for b in range(1, n+1):
            graph[a][b] = min(graph[a][b], graph[a][k]+graph[k][b])

x, k = map(int, input().split())
res = graph[1][k] + graph[k][x]
if res >= INF:
    print(-1)
else:
    print(res)
# Out:
# 5 7
# 1 2
# 1 3
# 1 4
# 2 4
# 3 4
# 3 5
# 4 5
# 4 5
# 3

# %%
# 전보 품
import heapq

INF = int(1e9)

n, m, c = map(int, input().split())
graph = [[] for _ in range(n+1)]
distance = [INF]* (n+1)
for _ in range(m):
    x, y, z = map(int, input().split())
    graph[x].append((y, z))
    
def dijkstra(start):
    q = []
    heapq.heappush(q, (0, start))
    distance[start] = 0
    while q:
        dist, now = heapq.heappop(q)
        if distance[now] < dist:
            continue
        for i in graph[now]:
            cost = dist + i[1]
            if cost < distance[i[0]]:
                distance[i[0]] = cost
                heapq.heappush(q, (cost, i[0]))
dijkstra(c)
time = 0
cnt = 0
for i in range(1, n+1):
    if distance[i] != INF:
        time = max(distance[i], time)
        cnt += 1
        
print(cnt-1, time) # 자기 자신 제외
# Out:
# 3 2 1
# 1 2 4
# 1 3 2
# 2 4

# %%
# 플로이드 품
INF = int(1e9)

n = int(input())
m = int(input())
graph = [[INF]*(n+1) for _ in range(n+1)]

for a in range(1, n+1):
    for b in range(1, n+1):
        if a == b:
            graph[a][b] = 0

for _ in range(m):
    a, b, c = map(int, input().split())
    graph[a][b] = min(c, graph[a][b]) # 중복된 값 들어갈 수 있음

for k in range(1, n+1):
    for a in range(1, n+1):
        for b in range(1, n+1):
            if graph[a][b] == 0:
                continue
            graph[a][b] = min(graph[a][b], graph[a][k] + graph[k][b])
                

for a in range(1, n+1):
    for b in range(1, n+1):
        if graph[a][b] == INF:
            print("0", end=' ')
        else:
            print(graph[a][b], end= ' ')
    print()
# Out:
# 5
# 14
# 1 2 2
# 1 3 3
# 1 4 1
# 1 5 10
# 2 4 2
# 3 4 1
# 3 5 1
# 4 5 3
# 3 5 10
# 3 1 8
# 1 4 2
# 5 1 7
# 3 4 2
# 5 2 4
# 0 2 3 1 4
# 12 0 15 2 5
# 8 5 0 1 1
# 10 7 13 0 3
# 7 4 10 6 0

# %%
# 정확한 순위 맞은지를 모르겠다;;;
import heapq
import sys
#input = sys.stdin.readline
INF = int(1e9)

n, m = map(int, input().split())
distance = [INF] * (n+1)
graph = [[] for _ in range(n+1)]

for _ in range(m):
    a, b = map(int, input().split())
    graph[a].append((b, 1))

def dijkstra(start):
    distance = [INF] * (n+1)
    cnt = 0
    q = []
    heapq.heappush(q, (0, start))
    distance[start] = 0
    while q:
        dist, now = heapq.heappop(q)
        cnt+=1
        if distance[now] < dist:
            continue
        for i in graph[now]:
            cost = dist + i[1]
            if cost < distance[i[0]]:
                distance[i[0]] = cost
                heapq.heappush(q, (cost, i[0]))
    return cnt

res =  []
for i in range(1, n+1):
    res.append(dijkstra(i))

print(res.count(n-1))
'''첫번째 생각은 플로이드 워셜로 모든 경로 탐색하게 하고 건너서 갈 수
있으면 갈수 있는것 1로두고 inf아닌 개수 세기...'''
# Out:
# 6 6
# 1 5
# 3 4
# 4 2
# 4 6
# 5 2
# 5 4
# 1

# %%
# 화성탐사 품 쓰바~!!!굳잡
import heapq
direction = [(1, 0), (0, 1), (-1, 0), (0, -1)]
INF = int(1e9)
test = int(input())

for i in range(test):
    graph = []
    n = int(input())
    for i in range(n):
        graph.append(list(map(int, input().split())))
    q = []
    heapq.heappush(q, (0, 0, graph[0][0]))
    distance = [[INF]*(n) for _ in range(n)]
    
    while q:
        x, y, cost = heapq.heappop(q)
        #distance[x][y] = graph[x][y]
        for dx, dy in direction:
            rx, ry = x+dx, y+dy
            if 0 <= rx < n and 0 <= ry < n:
                money = cost + graph[rx][ry]
                if distance[rx][ry] > money:
                    heapq.heappush(q, (rx, ry, money))
                    distance[rx][ry] = money
    print(distance[n-1][n-1])
# Out:
# 3
# 3
# 5 5 4
# 3 9 1
# 3 2 7
# 20
# 5
# 3 7 2 0 1
# 2 8 0 9 1
# 1 2 1 8 1
# 9 8 9 2 0
# 3 6 5 1 5
# 19
# 7
# 9 0 5 1 1 5 3
# 4 1 2 1 6 5 3
# 0 7 6 1 6 8 5
# 1 1 7 8 3 2  3
# 9 4 0 7 6 4 1
# 5 8 3 2 4 8 3
# 7 4 8 4 8 3 4
# 36

# %%
# 숨바꼭질
import heapq
INF = int(1e9)

n, m = map(int, input().split())
graph = [[INF]*(n+1) for _ in range(n+1)]


for a in range(1, n+1):
    for b in range(1, n+1):
        if a == b:
            graph[a][b] = 0
            
for _ in range(m):
    a, b = map(int, input().split())
    graph[a][b] = graph[b][a] = 1

for k in range(1, n+1):
    for a in range(1, n+1):
        for b in range(1, n+1):
            graph[a][b] = min(graph[a][b], graph[a][k]+graph[k][b])
maximum = 0
for a in range(1, n+1):
    if graph[1][a] != INF & maximum < graph[1][a]:
        maximum = graph[1][a]

        
cnt = graph[1].count(maximum)
idx = graph[1].index(maximum)
print(idx, maximum, cnt)
# Out:
# 6 7
# 3 6
# 4 3
# 3 2
# 1 3
# 1 2
# 2 4
# 5 2
# 4 2 3
