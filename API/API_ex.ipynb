# %%
import requests

target = "http://google.com"
response = requests.get(url=target)
print(response.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="6uwbo6hFLHmlV97Ly7APbQ==">(function(){window.google={kEI:'QemUYaTQK8GnoASQrL2IAg',kEXPI:'0,1302536,56873,6058,207,4804,2316,383,246,5,1354,5251,1122515,1197718,329549,51224,16114,28684,17572,4858,1362,9290,3023,17586,4020,978,13228,3847,10622,21822,919,5970,704,1279,2212,530,149,1103,840,2196,4101,109,3405,606,2023,1733,43,521,14670,3227,1989,858,5,4774,7580,5096,7539,8781,908,2,3555,13142,3,576,6460,148,13975,4,1528,2304,7039,4684,2014,13611,4764,2658,6701,656,30,11412,2216,2305,2132,16786,5797,2560,4094,3138,6,908,3,3541,1,14261,2263,283,912,5992,18443,2,3036,10986,1931,4318,1271,128,616,5852,9405,49,1009,1160,1266,5433,2380,2719,14170,4127,2,6,350,7369,2124,2444,2577,3136,274,271,1107,1362,1563,2,1,3,2
# ...

# %%
import json

user = {
    "id" : "hd",
    "password" : "1111",
    "age" : 30,
    "hobby" : [
        "foodball",
        "music"
    ]
}

json_data = json.dumps(user, indent = 4)
print(json_data)
# Out:
# {
#     "id": "hd",
#     "password": "1111",
#     "age": 30,
#     "hobby": [
#         "foodball",
#         "music"
#     ]
# }

# %%
# import json

# user = {
#     "id" : "hd",
#     "password" : "1111",
#     "age" : 30,
#     "hobby" : [
#         "foodball",
#         "music"
#     ]
# }

json_data = json.dumps(user)
data = json.loads(json_data)
print(data)
# Out:
# {'id': 'hd', 'password': '1111', 'age': 30, 'hobby': ['foodball', 'music']}

# %%
# 파일로저장
with open("user.json", "w", encoding="utf-8") as file:
    json.dump(user, file, indent=4)

# %%
import requests

target = "https://jsonplaceholder.typicode.com/users"
response = requests.get(url=target)
data = response.json()
# print(data)

name_list = []

for user in data:
    name_list.append(user['name'])
print(name_list)
# Out:
# ['Leanne Graham', 'Ervin Howell', 'Clementine Bauch', 'Patricia Lebsack', 'Chelsey Dietrich', 'Mrs. Dennis Schulist', 'Kurtis Weissnat', 'Nicholas Runolfsdottir V', 'Glenna Reichert', 'Clementina DuBuque']

# %%
import requests
import json

# /4f4756506d65617337335866576365/json/


target = "http://openapi.seoul.go.kr:8088/4f4756506d65617337335866576365/json/Corona19Status/1/1000"
print(target)
response = requests.get(url = target)
data = response.json()
for cov in data['Corona19Status']['row']:
    print(cov['CORONA19_ID'], "\t", cov['CORONA19_AREA'], "\t", cov['CORONA19_IDATE'])
# Out:
